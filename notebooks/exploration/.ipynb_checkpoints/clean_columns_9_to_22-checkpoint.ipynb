# %% [markdown]
# ## import section

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv('../../../Divar.csv', index_col=0)
df.head(5)
# Out:
# C:\Users\Alireza\AppData\Local\Temp\ipykernel_4172\2754723844.py:1: DtypeWarning: Columns (11,27,29,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../../Divar.csv', index_col=0)
#           cat2_slug       cat3_slug city_slug neighborhood_slug  \
# 0    temporary-rent           villa     karaj         mehrshahr
# 1  residential-sell  apartment-sell    tehran           gholhak
# 2  residential-rent  apartment-rent    tehran             tohid
# 3   commercial-rent     office-rent    tehran          elahiyeh
# 4  residential-sell  apartment-sell   mashhad          emamreza
#
#       created_at_month    user_type  \
# 0  2024-08-01 00:00:00  مشاور املاک
# 1  2024-05-01 00:00:00  مشاور املاک
# 2  2024-10-01 00:00:00          NaN
# 3  2024-06-01 00:00:00          NaN
# 4  2024-05-01 00:00:00  مشاور املاک
#
#                                          description  \
# 0  ۵۰۰متر\n۲۰۰متر بنا دوبلکس\n۳خواب\nاستخر آبگرم ...
# 1  دسترسی عالی به مترو و شریعتی \nمشاعات تمیز \nب...
# 2                                    تخلیه پایان ماه
# 3  فرشته تاپ لوکیشن\n۹۰ متر موقعیت اداری\nیک اتاق...
# 4  هلدینگ ساختمانی اکبری\n\nهمراه شما هستیم برای ...
#
#                                               title rent_mode  rent_value  \
# 0  باغ ویلا اجاره روزانه استخر داخل لشکرآباد سهیلیه       NaN         NaN
# 1                           ۶۰ متر قلهک فول امکانات       NaN         NaN
# 2                          آپارتمان ۳ خوابه ۱۳۲ متر     مقطوع  26000000.0
# 3           فرشته ۹۰ متر دفتر کار مدرن موقعیت اداری     مقطوع  95000000.0
# 4                  ۱۱۵ متری/شمالی رو به آفتاب/اکبری       NaN         NaN
#
#    ... property_type regular_person_capacity extra_person_capacity  \
# 0  ...           NaN                     4.0                     6
# 1  ...           NaN                     NaN                   NaN
# 2  ...           NaN                     NaN                   NaN
# 3  ...           NaN                     NaN                   NaN
# 4  ...           NaN                     NaN                   NaN
#
#    cost_per_extra_person rent_price_on_regular_days  \
# 0               350000.0                  1500000.0
# 1                    NaN                        NaN
# 2                    NaN                        NaN
# 3                    NaN                        NaN
# 4                    NaN                        NaN
#
#    rent_price_on_special_days rent_price_at_weekends location_latitude  \
# 0                3.500000e+09              3500000.0         35.811684
# 1                         NaN                    NaN               NaN
# 2                         NaN                    NaN         35.703865
# 3                         NaN                    NaN               NaN
# 4                         NaN                    NaN               NaN
#
#    location_longitude  location_radius
# 0           50.936600            500.0
# 1                 NaN            500.0
# 2           51.373459              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### Slicing my part

# %%
price_df_922 = df.iloc[:,8:22]
price_df_5260 = df.iloc[:,51:57]
price_df_922.columns, len(price_df_922.columns), price_df_5260.columns, len(price_df_5260.columns)
# Out:
# (Index(['rent_mode', 'rent_value', 'rent_to_single', 'rent_type', 'price_mode',
#         'price_value', 'credit_mode', 'credit_value', 'rent_credit_transform',
#         'transformable_price', 'transformable_credit', 'transformed_credit',
#         'transformable_rent', 'transformed_rent'],
#        dtype='object'),
#  14,
#  Index(['regular_person_capacity', 'extra_person_capacity',
#         'cost_per_extra_person', 'rent_price_on_regular_days',
#         'rent_price_on_special_days', 'rent_price_at_weekends'],
#        dtype='object'),
#  6)

# %%
price_df_922.head()
# Out:
#   rent_mode  rent_value rent_to_single rent_type price_mode   price_value  \
# 0       NaN         NaN            NaN       NaN        NaN           NaN
# 1       NaN         NaN            NaN       NaN      مقطوع  8.500000e+09
# 2     مقطوع  26000000.0            NaN       NaN        NaN           NaN
# 3     مقطوع  95000000.0            NaN       NaN        NaN           NaN
# 4       NaN         NaN            NaN       NaN      مقطوع  5.750000e+09
#
#   credit_mode  credit_value rent_credit_transform transformable_price  \
# 0         NaN           NaN                   NaN                 NaN
# 1         NaN           NaN                   NaN                 NaN
# 2       مقطوع   750000000.0                 False               False
# 3       مقطوع   950000000.0                 False               False
# 4         NaN           NaN                   NaN                 NaN
#
#    transformable_credit  transformed_credit  transformable_rent  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2           750000000.0                 NaN          26000000.0
# 3           950000000.0                 NaN          95000000.0
# 4                   NaN                 NaN                 NaN
#
#    transformed_rent
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
price_df_5260.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   regular_person_capacity     29870 non-null  float64
#  1   extra_person_capacity       24009 non-null  object
#  2   cost_per_extra_person       10241 non-null  float64
#  3   rent_price_on_regular_days  18068 non-null  float64
#  4   rent_price_on_special_days  10463 non-null  float64
#  5   rent_price_at_weekends      13551 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 53.4+ MB

# %%
price_df_5260.head()
# Out:
#    regular_person_capacity extra_person_capacity  cost_per_extra_person  \
# 0                      4.0                     6               350000.0
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
#
#    rent_price_on_regular_days  rent_price_on_special_days  \
# 0                   1500000.0                3.500000e+09
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    rent_price_at_weekends
# 0               3500000.0
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %% [markdown]
# ## Data Exploration

# %%
price_df_922.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000000 entries, 0 to 999999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   rent_mode              352994 non-null  object
#  1   rent_value             351322 non-null  float64
#  2   rent_to_single         19 non-null      object
#  3   rent_type              103961 non-null  object
#  4   price_mode             573606 non-null  object
#  5   price_value            568346 non-null  float64
#  6   credit_mode            352994 non-null  object
#  7   credit_value           352095 non-null  float64
#  8   rent_credit_transform  352985 non-null  object
#  9   transformable_price    352894 non-null  object
#  10  transformable_credit   352085 non-null  float64
#  11  transformed_credit     72409 non-null   float64
#  12  transformable_rent     351248 non-null  float64
#  13  transformed_rent       72409 non-null   float64
# dtypes: float64(7), object(7)
# memory usage: 114.4+ MB

# %% [markdown]
# ### object columns

# %%
for col in price_df_922.columns:
    if price_df_922[col].dtype == 'object':    
        print(price_df_922[col].value_counts())
        print('-------------------')
# Out:
# rent_mode
# مقطوع     292081
# مجانی      59241
# توافقی      1672
# Name: count, dtype: int64
# -------------------
# rent_to_single
# True     18
# False     1
# Name: count, dtype: int64
# -------------------
# rent_type
# rent_credit    103814
# full_credit       147
# Name: count, dtype: int64
# -------------------
# price_mode
# مقطوع     566444
# توافقی      5260
# مجانی       1902
# Name: count, dtype: int64
# -------------------
# credit_mode
# مقطوع     349231
# مجانی       2864
# توافقی       899
# Name: count, dtype: int64
# -------------------
# rent_credit_transform
# False    326561
# True      26424
# Name: count, dtype: int64
# -------------------
# transformable_price
# False    279778
# True      73116
# Name: count, dtype: int64
# -------------------

# %% [markdown]
# ### for scaler columns

# %%
price_df_922.describe()
# Out:
#          rent_value   price_value  credit_value  transformable_credit  \
# count  3.513220e+05  5.683460e+05  3.520950e+05          3.520850e+05
# mean   4.102299e+10  1.736537e+10  4.872084e+10          4.872222e+10
# std    3.807534e+12  5.878739e+11  4.341346e+12          4.341407e+12
# min    0.000000e+00  0.000000e+00  0.000000e+00          0.000000e+00
# 25%    1.111110e+05  1.400000e+09  1.000000e+08          1.000000e+08
# 50%    5.000000e+06  2.840000e+09  2.500000e+08          2.500000e+08
# 75%    1.200000e+07  5.900000e+09  5.000000e+08          5.000000e+08
# max    1.000000e+15  1.000000e+14  1.000000e+15          1.000000e+15
#
#        transformed_credit  transformable_rent  transformed_rent
# count        7.240900e+04        3.512480e+05      7.240900e+04
# mean         8.557025e+09        4.103164e+10      1.619934e+07
# std          2.064576e+12        3.807935e+12      5.217890e+07
# min          0.000000e+00        0.000000e+00      0.000000e+00
# 25%          2.000000e+08        1.111110e+05      1.000000e+06
# 50%          4.000000e+08        5.000000e+06      6.000000e+06
# 75%          8.500000e+08        1.200000e+07      1.500000e+07
# max          5.555556e+14        1.000000e+15      3.000000e+09

# %%
temp_t = price_df_922[price_df_922['rent_credit_transform'] == True]
temp_f = price_df_922[price_df_922['rent_credit_transform'] == False]

# %%
temp_t.head(5)
# Out:
#     rent_mode  rent_value rent_to_single    rent_type price_mode  price_value  \
# 11      مجانی         0.0            NaN  rent_credit        NaN          NaN
# 21      مقطوع    100000.0            NaN  rent_credit        NaN          NaN
# 48      مجانی         0.0            NaN  rent_credit        NaN          NaN
# 183     مقطوع  17000000.0            NaN  rent_credit        NaN          NaN
# 249     مجانی         0.0            NaN  rent_credit        NaN          NaN
#
#     credit_mode  credit_value rent_credit_transform transformable_price  \
# 11        مقطوع  1.200000e+09                  True                True
# 21        مقطوع  9.000000e+08                  True                True
# 48        مقطوع  1.500000e+09                  True                True
# 183       مقطوع  4.000000e+08                  True                True
# 249       مقطوع  5.000000e+08                  True                True
#
#      transformable_credit  transformed_credit  transformable_rent  \
# 11           1.200000e+09         800000000.0                 0.0
# 21           9.000000e+08         200000000.0            100000.0
# 48           1.500000e+09         750000000.0                 0.0
# 183          4.000000e+08         450000000.0          17000000.0
# 249          5.000000e+08         400000000.0                 0.0
#
#      transformed_rent
# 11         12000000.0
# 21         21000000.0
# 48         22500000.0
# 183        16000000.0
# 249         3000000.0

# %%
temp_f.head()
# Out:
#    rent_mode  rent_value rent_to_single    rent_type price_mode  price_value  \
# 2      مقطوع  26000000.0            NaN          NaN        NaN          NaN
# 3      مقطوع  95000000.0            NaN          NaN        NaN          NaN
# 5      مقطوع   6000000.0            NaN          NaN        NaN          NaN
# 6      مقطوع  16000000.0            NaN          NaN        NaN          NaN
# 15     مقطوع  18000000.0            NaN  rent_credit        NaN          NaN
#
#    credit_mode  credit_value rent_credit_transform transformable_price  \
# 2        مقطوع   750000000.0                 False               False
# 3        مقطوع   950000000.0                 False               False
# 5        مقطوع   250000000.0                 False                True
# 6        مقطوع   150000000.0                 False               False
# 15       مقطوع   100000000.0                 False               False
#
#     transformable_credit  transformed_credit  transformable_rent  \
# 2            750000000.0                 NaN          26000000.0
# 3            950000000.0                 NaN          95000000.0
# 5            250000000.0         400000000.0           6000000.0
# 6            150000000.0                 NaN          16000000.0
# 15           100000000.0                 NaN          18000000.0
#
#     transformed_rent
# 2                NaN
# 3                NaN
# 5                1.0
# 6                NaN
# 15               NaN

# %% [markdown]
# ### drop some unneccessary columns

# %% [markdown]
# از آنجایی که میخوام ی فیچر توتال پرایس بسازیم بسیاری از ستون های مربوط به اجاره و رهن و قیمت برای مااستفاده ای ندارند

# %%
price_df_922_edited = price_df_922.copy()
#price_df_922_edited = price_df_922_edited[['rent_value', 'price_value', 'credit_value', 'transformed_credit', 'transformed_rent']]
price_df_922_edited = price_df_922_edited[['rent_value', 'price_value', 'credit_value']]
price_df_922_edited.head()
# Out:
#    rent_value   price_value  credit_value
# 0         NaN           NaN           NaN
# 1         NaN  8.500000e+09           NaN
# 2  26000000.0           NaN   750000000.0
# 3  95000000.0           NaN   950000000.0
# 4         NaN  5.750000e+09           NaN

# %%
price_df_922_edited.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000000 entries, 0 to 999999
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   rent_value    351322 non-null  float64
#  1   price_value   568346 non-null  float64
#  2   credit_value  352095 non-null  float64
# dtypes: float64(3)
# memory usage: 30.5 MB

# %%
mask = (
    price_df_922_edited['rent_value'].isna() &
    price_df_922_edited['credit_value'].isna() &
    price_df_922_edited['price_value'].isna()
)
len(price_df_922_edited[mask])
# Out:
# 79429

# %%
def ShowCorrMatrix(df):
    corr_matrix = df.corr()
    plt.figure(figsize=(8,5))
    sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
    plt.show()

ShowCorrMatrix(price_df_922_edited)

# %% [markdown]
# ### اضافه کردن ستون تایتل و توضیحات به منظور پر کردن مقادیر ناموجود با استفاده از رجکس

# %%
D_t = df.copy()
D_t = D_t[['title','description']]
D_rent = price_df_5260[['rent_price_on_regular_days','rent_price_on_special_days','rent_price_at_weekends']]
#price_df = pd.concat([df[['cat2_slug', 'cat3_slug']],D_t, price_df_922_edited, D_rent], axis=1)
price_df = pd.concat([D_t, price_df_922_edited, D_rent], axis=1)
price_df.head()
# Out:
#                                               title  \
# 0  باغ ویلا اجاره روزانه استخر داخل لشکرآباد سهیلیه
# 1                           ۶۰ متر قلهک فول امکانات
# 2                          آپارتمان ۳ خوابه ۱۳۲ متر
# 3           فرشته ۹۰ متر دفتر کار مدرن موقعیت اداری
# 4                  ۱۱۵ متری/شمالی رو به آفتاب/اکبری
#
#                                          description  rent_value  \
# 0  ۵۰۰متر\n۲۰۰متر بنا دوبلکس\n۳خواب\nاستخر آبگرم ...         NaN
# 1  دسترسی عالی به مترو و شریعتی \nمشاعات تمیز \nب...         NaN
# 2                                    تخلیه پایان ماه  26000000.0
# 3  فرشته تاپ لوکیشن\n۹۰ متر موقعیت اداری\nیک اتاق...  95000000.0
# 4  هلدینگ ساختمانی اکبری\n\nهمراه شما هستیم برای ...         NaN
#
#     price_value  credit_value  rent_price_on_regular_days  \
# 0           NaN           NaN                   1500000.0
# 1  8.500000e+09           NaN                         NaN
# 2           NaN   750000000.0                         NaN
# 3           NaN   950000000.0                         NaN
# 4  5.750000e+09           NaN                         NaN
#
#    rent_price_on_special_days  rent_price_at_weekends
# 0                3.500000e+09               3500000.0
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   title                       999946 non-null   object
#  1   description                 1000000 non-null  object
#  2   rent_value                  351322 non-null   float64
#  3   price_value                 568346 non-null   float64
#  4   credit_value                352095 non-null   float64
#  5   rent_price_on_regular_days  18068 non-null    float64
#  6   rent_price_on_special_days  10463 non-null    float64
#  7   rent_price_at_weekends      13551 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 68.7+ MB

# %% [markdown]
# ### ایجاد ستون اجاره تقریبی برای تخمین اجاره ماهانه با استفاده ستون های مربوط به اجاره روزانه

# %%
cols = [
    'rent_price_on_regular_days',
    'rent_price_on_special_days',
    'rent_price_at_weekends'
]

## از میانگین گیری ساده برای ترکیب سه ستون فوق برای تخمین اجاره ماهانه استفاده شده است 
price_df['estimate_rent'] = price_df[cols].mean(axis=1, skipna=True) * 30

mask_all_nan = price_df[cols].isna().all(axis=1)
price_df.loc[mask_all_nan, 'estimate_rent'] = np.nan

# %%
weights = {
    'rent_price_on_regular_days': 5/7,
    'rent_price_at_weekends': 2/7,
    'rent_price_on_special_days': 0.1  
}

# محاسبه میانگین وزنی
def weighted_mean(row):
    total, wsum = 0, 0
    for col in cols:
        val = row[col]
        if not pd.isna(val):
            total += val * weights[col]
            wsum += weights[col]
    return total / wsum if wsum > 0 else np.nan

price_df['weighted_estimate_rent'] = price_df[cols].apply(weighted_mean, axis=1) * 30

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000000 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   title                       999946 non-null   object
#  1   description                 1000000 non-null  object
#  2   rent_value                  351322 non-null   float64
#  3   price_value                 568346 non-null   float64
#  4   credit_value                352095 non-null   float64
#  5   rent_price_on_regular_days  18068 non-null    float64
#  6   rent_price_on_special_days  10463 non-null    float64
#  7   rent_price_at_weekends      13551 non-null    float64
#  8   estimate_rent               18272 non-null    float64
#  9   weighted_estimate_rent      18272 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 83.9+ MB

# %%
price_df['estimate_rent'].describe()
# Out:
# count    1.827200e+04
# mean     4.348215e+12
# std      2.105439e+14
# min      0.000000e+00
# 25%      1.400000e+07
# 50%      2.800000e+07
# 75%      6.300000e+07
# max      1.501802e+16
# Name: estimate_rent, dtype: float64

# %%
price_df['weighted_estimate_rent'].describe()
# Out:
# count    1.827200e+04
# mean     4.265369e+12
# std      2.101278e+14
# min      0.000000e+00
# 25%      1.305195e+07
# 50%      2.571429e+07
# 75%      5.785714e+07
# max      1.501802e+16
# Name: weighted_estimate_rent, dtype: float64

# %%
len(price_df[~price_df.weighted_estimate_rent.isna()])
# Out:
# 18272

# %% [markdown]
# ### جایگرین کردن مقدار اجاره تخمینی در ستون مقدار اجاره در سطر هایی که هر سه ستون اجاره و رهن و قیمت ناموجود هستند

# %%
###  استفاده از میانگین وزن دار 
price_df_copy = price_df.copy()
mask = (
    price_df_copy['rent_value'].isna() &
    price_df_copy['credit_value'].isna() &
    price_df_copy['price_value'].isna() &
    price_df_copy['weighted_estimate_rent'].notna()
)

price_df_copy.loc[mask, 'rent_value'] = price_df_copy.loc[mask, 'weighted_estimate_rent']
price_df_copy = price_df_copy.drop('estimate_rent', axis =1)
price_df_copy = price_df_copy.drop('weighted_estimate_rent', axis =1)

# %% [markdown]
# ### تعداد ستون هایی مقادیر رهن و اجاره و قیمت هر سه یا هم ناموجودند قبل از جایگذاری اجاره تخمینی

# %%
temp_3nan = price_df[price_df['rent_value'].isna() & price_df['price_value'].isna() & price_df['credit_value'].isna()]
print('before : ',len(temp_3nan))
# Out:
# before :  79429

# %% [markdown]
# ### تعداد ستون هایی مقادیر رهن و اجاره و قیمت هر سه یا هم ناموجودند بعد از جایگذاری اجاره تخمینی

# %%
temp_3nan = price_df_copy[price_df_copy['rent_value'].isna() & price_df_copy['price_value'].isna() & price_df_copy['credit_value'].isna()]
print('after : ',len(temp_3nan))
# Out:
# before :  61157

# %%
### ستون هایی که هر  ستا پر باشند
temp_0nan = price_df[~price_df['rent_value'].isna() & ~price_df['price_value'].isna() & ~price_df['credit_value'].isna()]
print(len(temp_0nan))
temp_0nan1 = price_df_copy[~price_df_copy['rent_value'].isna() & ~price_df_copy['price_value'].isna() & ~price_df_copy['credit_value'].isna()]
print(len(temp_0nan1))
# Out:
# 0
# 0

# %%
### rent_credit
temp_rentcredit = price_df[~price_df['rent_value'].isna() & price_df['price_value'].isna() & ~price_df['credit_value'].isna()]
print(len(temp_rentcredit))
temp_rentcredit1 = price_df_copy[~price_df_copy['rent_value'].isna() & price_df_copy['price_value'].isna() & ~price_df_copy['credit_value'].isna()]
print(len(temp_rentcredit1))
# Out:
# 351192
# 351192

# %%
### full_credit
temp_fullcredit = price_df[price_df['rent_value'].isna() & price_df['price_value'].isna() & ~price_df['credit_value'].isna()]
print(len(temp_fullcredit))
temp_fullcredit1 = price_df_copy[price_df_copy['rent_value'].isna() & price_df_copy['price_value'].isna() & ~price_df_copy['credit_value'].isna()]
print(len(temp_fullcredit1))
# Out:
# 903
# 903

# %%
### فقط اجاره ناموجود نیست 
temp_fullrent = price_df[~price_df['rent_value'].isna() & price_df['price_value'].isna() & price_df['credit_value'].isna()]
print('before :',len(temp_fullrent))
temp_fullrent1 = price_df_copy[~price_df_copy['rent_value'].isna() & price_df_copy['price_value'].isna() & price_df_copy['credit_value'].isna()]
print('after: ',len(temp_fullrent1))
# Out:
# before : 130
# after:  18402

# %%
temp_price = price_df[price_df['rent_value'].isna() & ~price_df['price_value'].isna() & price_df['credit_value'].isna()]
print(len(temp_price))
temp_price1 = price_df_copy[price_df_copy['rent_value'].isna() & ~price_df_copy['price_value'].isna() & price_df_copy['credit_value'].isna()]
print(len(temp_price1))
# Out:
# 568346
# 568346

# %% [markdown]
# #### حذف کردن برخی ستون های اضافی

# %%
#price_df_copy = price_df_copy.drop(['rent_price_on_regular_days','rent_price_on_special_days','rent_price_at_weekends','cat2_slug','cat3_slug'],axis=1)
price_df_copy = price_df_copy.drop(['rent_price_on_regular_days','rent_price_on_special_days','rent_price_at_weekends'],axis=1)
price_df_copy_final = price_df_copy.copy()
price_df_copy_final
# Out:
#                                                     title  \
# 0        باغ ویلا اجاره روزانه استخر داخل لشکرآباد سهیلیه
# 1                                 ۶۰ متر قلهک فول امکانات
# 2                                آپارتمان ۳ خوابه ۱۳۲ متر
# 3                 فرشته ۹۰ متر دفتر کار مدرن موقعیت اداری
# 4                        ۱۱۵ متری/شمالی رو به آفتاب/اکبری
# ...                                                   ...
# 999995                        آپارتمان ۱۸۰ متری وحدت غربی
# 999996       آپارتمان  ۱۱۰  متری     سعادت   آباد    دریا
# 999997  منزل فروشی.  خیابان انقلاب   نرسیده به کارخانه...
# 999998                    مجتمع ویلایی کنار ساحل پاسداران
# 999999                       ۴۰ متر/ یک خواب /فول بازسازی
#
#                                               description    rent_value  \
# 0       ۵۰۰متر\n۲۰۰متر بنا دوبلکس\n۳خواب\nاستخر آبگرم ...  9.601948e+09
# 1       دسترسی عالی به مترو و شریعتی \nمشاعات تمیز \nب...           NaN
# 2                                         تخلیه پایان ماه  2.600000e+07
# 3       فرشته تاپ لوکیشن\n۹۰ متر موقعیت اداری\nیک اتاق...  9.500000e+07
# 4       هلدینگ ساختمانی اکبری\n\nهمراه شما هستیم برای ...           NaN
# ...                                                   ...           ...
# 999995  ~~~مشاورین املاک قبادی~~~\n■جنوبی تک واحدی\n■د...           NaN
# 999996  نوساز     \n\n تک واحدی\n\nشخصی  ساز\n\nروف گا...  4.500000e+07
# 999997  سلام ودرود\nفروش منزل مسکونی واقع در خیابان ان...           NaN
# 999998  سویت بدون خواب (روبه دریا و معمولی)\nسویت ۱خوا...  9.000000e+07
# 999999  ⚜️املاک بزرگ میلیارد⚜️\n✅️۴۰ متر یک خواب\n✅️نو...  0.000000e+00
#
#          price_value  credit_value
# 0                NaN           NaN
# 1       8.500000e+09           NaN
# 2                NaN  7.500000e+08
# 3                NaN  9.500000e+08
# 4       5.750000e+09           NaN
# ...              ...           ...
# 999995  7.470000e+09           NaN
# 999996           NaN  1.000000e+09
# 999997  3.200000e+09           NaN
# 999998           NaN           NaN
# 999999           NaN  3.500000e+08
#
# [1000000 rows x 5 columns]

# %% [markdown]
# ### handling missing values with Regex

# %% [markdown]
# الان باید برای ستون هایی باقیمانده که هر سه مقدار رهن و اجاره و قیمت در آنها ناموجود هست با استفاده از رجکس، ستون تایتل و توضیحات تا حد امکان آنها را پر کنیم

# %%
import re


pd.set_option("display.max_colwidth", None)

def persian_to_english_digits(s):
    if not isinstance(s, str):
        return s
    persian_digits = '۰۱۲۳۴۵۶۷۸۹'
    english_digits = '0123456789'
    trans_table = str.maketrans(persian_digits, english_digits)
    return s.translate(trans_table)

def text_to_number(num_str, unit=None):
    num_str = num_str.replace(',', '').replace('٫', '.').replace('/', '.')
    try:
        value = float(num_str)
    except:
        return None
    
    if unit:
        unit = unit.strip()
        if 'میلیارد' in unit:
            value *= 1_000_000_000
        elif 'میلیون' in unit:
            value *= 1_000_000
        elif 'هزار' in unit:
            value *= 1_000
        # اگر فقط "تومان" یا "ریال" باشه → همون مقدار می‌مونه
    return value

def extract_values(text):
    if pd.isna(text):
        return None, None, None
    
    text = persian_to_english_digits(text)

    rent, credit, price = None, None, None

    # الگوهای انعطاف‌پذیرتر
    rent_pattern   = r'اجاره[:\s]*([۰-۹0-9\.,٫/]+)\s*(میلیارد|میلیون|هزار|تومان|ریال)?'
    credit_pattern = r'رهن(?:\s*کامل)?[:\s]*([۰-۹0-9\.,٫/]+)\s*(میلیارد|میلیون|هزار|تومان|ریال)?'
    price_pattern  = r'(?:قیمت(?:\s*کل)?|مبلغ)[:\s]*([۰-۹0-9\.,٫/]+)\s*(میلیارد|میلیون|هزار|تومان|ریال)?'

    matches = re.findall(credit_pattern, text)
    if matches:
        num, unit = matches[0]
        credit = text_to_number(num, unit)

    # اجاره
    matches = re.findall(rent_pattern, text)
    if matches:
        num, unit = matches[0]
        rent = text_to_number(num, unit)

    # قیمت
    matches = re.findall(price_pattern, text)
    if matches:
        num, unit = matches[0]
        price = text_to_number(num, unit)

    return rent, credit, price



temp_3nan = price_df_copy[
    price_df_copy['rent_value'].isna() &
    price_df_copy['price_value'].isna() &
    price_df_copy['credit_value'].isna()
].copy()

# اجرای تابع روی title + description
temp_3nan[['rent_value_extracted', 'credit_value_extracted', 'price_value_extracted']] = (
    temp_3nan.apply(
        lambda row: pd.Series(
            extract_values(str(row['title']) + " " + str(row['description']))
        ), axis=1
    )
)

# %%
temp_3nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61157 entries, 42 to 999994
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   61151 non-null  object
#  1   description             61157 non-null  object
#  2   rent_value              0 non-null      float64
#  3   price_value             0 non-null      float64
#  4   credit_value            0 non-null      float64
#  5   rent_value_extracted    125 non-null    float64
#  6   credit_value_extracted  72 non-null     float64
#  7   price_value_extracted   1741 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 4.2+ MB

# %%
len(temp_3nan[
    ~temp_3nan['rent_value_extracted'].isna() |
    ~temp_3nan['credit_value_extracted'].isna() |
    ~temp_3nan['price_value_extracted'].isna() 
])
# Out:
# 1918

# %%
len(temp_3nan[~temp_3nan['price_value_extracted'].isna()][['title','description','price_value_extracted']])
# Out:
# 1741

# %% [markdown]
# #### استفاده از مدل زبانی برای استخراج مقادیر ناموجود در ستون های اجاره و رهن و قیمت

# %% [markdown]
# با توجه به اینکه استفاده از رجکس تاثیر چندانی نداشت به سمت این کار سوق داده شدیم

# %%
import re
import json
from openai import OpenAI
import tqdm

price_df_copy_1 = price_df_copy.copy()

client = OpenAI(api_key="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")  # کلید API اینجا

def extract_rent_credit_price_batch(texts):
    ads_text = "\n\n".join([f"{i+1}. {t}" for i, t in enumerate(texts)])

    prompt = f"""
The following texts are Persian real estate ads. Extract **deposit (رهن)**, **monthly rent (اجاره)**, and **price (قیمت کل ملک)** for each ad.

Rules:
1. Return results as a JSON array of objects in the same order as the ads.
2. Each object must have three fields: "credit", "rent", "price".
3. If a value is not mentioned, set it to null.
4. Convert Persian digits/words to numbers.
5. Consider ONLY numbers that:
   - Come immediately before the words "رهن", "اجاره", or "خرید".
   - Are followed by one of these units: "تومن", "میلیون تومن", "میلیارد تومن".
6. Units:
   - "میلیارد تومن" = *1,000,000,000
   - "میلیون تومن" = *1,000,000
   - "تومن" without میلیون/میلیارد usually means میلیون in rent and deposit, but in price if very small (<100) assume میلیارد.
7. Ignore any numbers not matching rule 5 (like phone numbers, distances, land area "متر", "متری", etc.).
8. If the word **"خرید"** appears, use the first valid number after it (with تومن/میلیون/میلیارد) as **price**.
9. Return only JSON. Example:
   [
     {{"credit": 50000000, "rent": 2000000, "price": null}},
     {{"credit": null, "rent": null, "price": 8500000000}}
   ]
"""

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt + "\n\nNow process the following ads:\n" + ads_text}],
        temperature=0,
    )

    raw = response.choices[0].message.content.strip()
    raw_clean = raw.strip('`').replace('json\n', '')

    try:
        results = json.loads(raw_clean)
        if not isinstance(results, list):
            raise ValueError("Not a list")
    except Exception as e:
        print("Parsing error:", e)
        results = [ {"credit": None, "rent": None, "price": None} ] * len(texts)

    return results


# ------------------------------
# فیلتر ردیف‌ها
# ------------------------------

BATCH_SIZE = 10
N_LIMIT =  100

mask = (
    price_df_copy_1['rent_value'].isna() &
    price_df_copy_1['credit_value'].isna() &
    price_df_copy_1['price_value'].isna()
)

rows_to_process = price_df[mask].head(N_LIMIT)

# ستون‌های خروجی اگر وجود ندارن بساز
for col in ["rent_value_ai", "credit_value_ai", "price_value_ai"]:
    if col not in price_df_copy_1.columns:
        price_df_copy_1[col] = np.nan

# پردازش دسته‌ای
for start in tqdm.tqdm(range(0, len(rows_to_process), BATCH_SIZE)):
    batch_rows = rows_to_process.iloc[start:start+BATCH_SIZE]

    texts = [
        f"{row['title']}. {row['description']}"
        for _, row in batch_rows.iterrows()
    ]

    if not texts:
        continue

    extracted = extract_rent_credit_price_batch(texts)

    for idx, values in zip(batch_rows.index, extracted):
        if values:
            price_df_copy_1.loc[idx, "credit_value_ai"] = values.get("credit")
            price_df_copy_1.loc[idx, "rent_value_ai"]   = values.get("rent")
            price_df_copy_1.loc[idx, "price_value_ai"]  = values.get("price")
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[74], line 89
#      86 if not texts:
#      87     continue
# ---> 89 extracted = extract_rent_credit_price_batch(texts)
#      91 for idx, values in zip(batch_rows.index, extracted):
#      92     if values:
#
# Cell In[74], line 37, in extract_rent_credit_price_batch(texts)
#      11     ads_text = "\n\n".join([f"{i+1}. {t}" for i, t in enumerate(texts)])
#      13     prompt = f"""
#      14 The following texts are Persian real estate ads. Extract **deposit (رهن)**, **monthly rent (اجاره)**, and **price (قیمت کل ملک)** for each ad.
#      15
#    (...)     34    ]
#      35 """
# ---> 37     response = client.chat.completions.create(
#      38         model="gpt-4o-mini",
#      39         messages=[{"role": "user", "content": prompt + "\n\nNow process the following ads:\n" + ads_text}],
#      40         temperature=0,
#      41     )
#      43     raw = response.choices[0].message.content.strip()
#      44     raw_clean = raw.strip('`').replace('json\n', '')
#
# File ~\anaconda3\envs\quera\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\quera\Lib\site-packages\openai\resources\chat\completions\completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File ~\anaconda3\envs\quera\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\quera\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************v9kA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
mask = (
    ~price_df_copy_1['rent_value_ai'].isna() |
    ~price_df_copy_1['credit_value_ai'].isna() |
    ~price_df_copy_1['price_value_ai'].isna()
)
print(len(price_df_copy_1[mask]))
price_df_copy_1[mask].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 mask = (
# ----> 2     ~price_df_copy_1['rent_value_ai'].isna() |
#       3     ~price_df_copy_1['credit_value_ai'].isna() |
#       4     ~price_df_copy_1['price_value_ai'].isna()
#       5 )
#       6 print(len(price_df_copy_1[mask]))
#       7 price_df_copy_1[mask].head()
#
# NameError: name 'price_df_copy_1' is not defined

# %% [markdown]
# ### ایجاد پارامتر جدید به نام قیمت کل

# %% [markdown]
# ### تابع `calculate_total_price`
#
# این تابع وظیفه دارد ستون جدیدی به نام **`total_price`** برای دیتافریم ایجاد کند که نشان‌دهنده‌ی «قیمت کل ملک» باشد.
# ورودی دیتافریم باید شامل سه ستون اصلی زیر باشد:
#
# - `price_value` → قیمت کل ملک (در صورت موجود بودن)
# - `credit_value` → مبلغ رهن
# - `rent_value` → مبلغ اجاره
#
# ---
#
# #### منطق محاسبه:
# 1. **اگر `price_value` مقدار داشته باشد**
#    → همان مقدار مستقیماً در ستون `total_price` قرار داده می‌شود.
#
# 2. **اگر `price_value` خالی باشد**
#    - اگر `rent_value` مقدار داشته باشد:
#      - اجاره به رهن معادل تبدیل می‌شود با نسبت پیش‌فرض:
#        \[
#        rent\_as\_credit = rent \times \frac{credit\_unit}{rent\_unit}
#        \]
#        (به طور پیش‌فرض: 30,000 تومان اجاره = 1,000,000 تومان رهن)
#      - سپس:
#        - اگر `credit_value` هم موجود بود → `(credit_value + rent_as_credit) × credit_to_total_ratio`
#        - اگر `credit_value` خالی بود → `(rent_as_credit × credit_to_total_ratio)`
#
#    - اگر `rent_value` خالی ولی `credit_value` مقدار داشته باشد:
#      - مقدار رهن × نسبت تبدیل به قیمت کل (`credit_to_total_ratio`).
#
#    - اگر هیچ‌کدام موجود نباشند → مقدار `total_price` برابر `NaN` خواهد شد.
#
# ---
#
# #### پارامترها:
# - `df` : دیتافریم ورودی شامل ستون‌های `rent_value`, `credit_value`, `price_value`
# - `rent_unit` (پیش‌فرض = 30000): میزان اجاره‌ای که معادل با `credit_unit` است
# - `credit_unit` (پیش‌فرض = 1000000): میزان رهن معادل با `rent_unit`
# - در حال حاضر `credit_to_total_ratio = 1` در نظر گرفته شده است (هر رهن کامل = همان قیمت کل)
#
# ---
#
# #### خروجی:
# - یک `pd.Series` به طول دیتافریم ورودی که مقادیر محاسبه‌شده‌ی **قیمت کل ملک** را برمی‌گرداند.

# %%
def calculate_total_price(df, rent_unit=30000, credit_unit=1000000):
    credit_to_total_ratio = 5  # فرض: هر رهن کامل = قیمت کل (قابل تغییر)
    rent_to_credit_ratio = credit_unit / rent_unit
    
    total_price = []
    
    for _, row in df.iterrows():
        price = row["price_value"]
        rent = row["rent_value"]
        credit = row["credit_value"]
        
      
        if pd.isna(price) and pd.isna(rent) and pd.isna(credit):
            total_price.append(np.nan)
            continue
        
        if not pd.isna(price):  
            total_price.append(price)
        
        else:
            if not pd.isna(rent):  
                rent_as_credit = rent * rent_to_credit_ratio
                
                if not pd.isna(credit):  
                    total_price.append((credit + rent_as_credit) * credit_to_total_ratio)
                else:
                    total_price.append(rent_as_credit * credit_to_total_ratio)
            
            elif not pd.isna(credit):  
                total_price.append(credit * credit_to_total_ratio)
            
            else:
                total_price.append(np.nan)
    
    return pd.Series(total_price, index=df.index)

# %% [markdown]
# ### مثال

# %%
df_1 = pd.DataFrame({
    "rent_value": [3000000, np.nan, 2000000, np.nan],
    "price_value": [np.nan, 8500000000, np.nan, np.nan],
    "credit_value": [50000000, np.nan, np.nan, 750000000]
})

df_1["total_price"] = calculate_total_price(df_1)
print(df_1)
# Out:
#    rent_value   price_value  credit_value   total_price
# 0   3000000.0           NaN    50000000.0  7.500000e+08
# 1         NaN  8.500000e+09           NaN  8.500000e+09
# 2   2000000.0           NaN           NaN  3.333333e+08
# 3         NaN           NaN   750000000.0  3.750000e+09

# %% [markdown]
# #### تنظیم کردن دیتاست ورودی

# %% [markdown]
# تعداد ستون هایی که پارامتر قیمت کل برای انها موجود نیست

# %%
temp_3nan = price_df_copy_final[price_df_copy_final['rent_value'].isna() & price_df_copy_final['price_value'].isna() & price_df_copy_final['credit_value'].isna()]
len(temp_3nan)
# Out:
# 61157

# %% [markdown]
# #### حذف ستون های اضافه

# %%
price_df_copy_final = price_df_copy_final.drop(['title','description'],axis=1)

# %%
price_df_copy_final.columns
# Out:
# Index(['rent_value', 'price_value', 'credit_value'], dtype='object')

# %% [markdown]
# #### ایجاد ستون

# %%
price_df_copy_final['total_price'] = calculate_total_price(price_df_copy_final)
price_df_copy_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000000 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   rent_value    369594 non-null  float64
#  1   price_value   568346 non-null  float64
#  2   credit_value  352095 non-null  float64
#  3   total_price   938843 non-null  float64
# dtypes: float64(4)
# memory usage: 38.1 MB

# %% [markdown]
# #### توزیع آماری ستون جدید

# %%
price_df_copy_final.total_price.describe()
# Out:
# count    9.388430e+05
# mean     1.649601e+13
# std      4.902687e+15
# min      0.000000e+00
# 25%      1.400000e+09
# 50%      2.675325e+09
# 75%      5.500000e+09
# max      2.503004e+18
# Name: total_price, dtype: float64

# %%
price_df_copy_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000000 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   rent_value    369594 non-null  float64
#  1   price_value   568346 non-null  float64
#  2   credit_value  352095 non-null  float64
#  3   total_price   938843 non-null  float64
# dtypes: float64(4)
# memory usage: 38.1 MB

# %% [markdown]
# ### حذف کردن ردیف هایی که مقدار قیمت کلی آن برابر با صفر است

# %%
price_df_copy_final[price_df_copy_final['total_price'] == 0]
# Out:
#         rent_value  price_value  credit_value  total_price
# 20             NaN          0.0           NaN          0.0
# 712            NaN          0.0           NaN          0.0
# 877            NaN          0.0           NaN          0.0
# 1243           NaN          0.0           NaN          0.0
# 1297           NaN          0.0           NaN          0.0
# ...            ...          ...           ...          ...
# 998686         NaN          0.0           NaN          0.0
# 998951         NaN          0.0           NaN          0.0
# 999411         NaN          0.0           NaN          0.0
# 999465         NaN          0.0           NaN          0.0
# 999982         NaN          0.0           NaN          0.0
#
# [2131 rows x 4 columns]

# %%
price_df_copy_final = price_df_copy_final[price_df_copy_final['total_price'] != 0]
price_df_copy_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 997869 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   rent_value    369369 non-null  float64
#  1   price_value   566444 non-null  float64
#  2   credit_value  352091 non-null  float64
#  3   total_price   936712 non-null  float64
# dtypes: float64(4)
# memory usage: 38.1 MB

# %% [markdown]
# ### هیستوگرام ستون قیمت کلی قبل از هندل کردن داده های پرت

# %%
price_df_copy_final['total_price'].hist(bins=50, figsize=(8,5))
plt.xlabel("total_price")
plt.ylabel("Frequency")
plt.show()

# %%
tmp = price_df_copy_final['total_price']
np.log10(tmp).hist(bins=50, figsize=(8,5))
plt.xlabel("total_price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### هندل کردن مقادیر پرت

# %%
price_df_copy_final['total_price_log'] = np.log(price_df_copy_final['total_price'])
price_df_copy_final['total_price'].describe()
# Out:
# count    9.367120e+05
# mean     1.653353e+13
# std      4.908261e+15
# min      1.000000e+00
# 25%      1.416667e+09
# 50%      2.700000e+09
# 75%      5.500000e+09
# max      2.503004e+18
# Name: total_price, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# مثلا ستون unit_price
plt.figure(figsize=(6,4))
sns.boxplot(y=price_df_copy_final['total_price_log'])
plt.title("Boxplot of unit_price")
plt.show()

# %%
def cap_outliers_iqr(df, column):
    """
    جایگزینی outlierها با حدود بالا و پایین بر اساس IQR
    """
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    print(Q1,Q3)
    # کپی از دیتافریم
    df_capped = df.copy()

    # جایگزینی مقادیر خارج از محدوده
    df_capped.loc[df_capped[column] < lower_bound, column] = lower_bound
    df_capped.loc[df_capped[column] > upper_bound, column] = upper_bound

    return df_capped

# %%
tmp_withoutlog = cap_outliers_iqr(price_df_copy_final,'total_price')
tmp_log = cap_outliers_iqr(price_df_copy_final,'total_price_log')
# Out:
# 1416666666.6666665 5500000000.0
# 21.071572531214628 22.428013929184836

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# مثلا ستون unit_price
plt.figure(figsize=(6,4))
sns.boxplot(y=tmp_log['total_price_log'])
plt.title("Boxplot of total_price with log")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# مثلا ستون unit_price
plt.figure(figsize=(6,4))
sns.boxplot(y=tmp_withoutlog['total_price'])
plt.title("Boxplot of total_price without log")
plt.show()

# %%
tmp_log['total_price'] = np.exp(tmp_log['total_price_log'])
tmp_log['total_price'].describe()
# Out:
# count    9.367120e+05
# mean     5.224096e+09
# std      7.536641e+09
# min      1.851933e+08
# 25%      1.416667e+09
# 50%      2.700000e+09
# 75%      5.500000e+09
# max      4.207317e+10
# Name: total_price, dtype: float64

# %%
tmp['total_price'].describe()
# Out:
# count    9.367120e+05
# mean     3.992078e+09
# std      3.498951e+09
# min      1.000000e+00
# 25%      1.416667e+09
# 50%      2.700000e+09
# 75%      5.500000e+09
# max      1.162500e+10
# Name: total_price, dtype: float64

# %%
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 997869 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   rent_value    369369 non-null  float64
#  1   price_value   566444 non-null  float64
#  2   credit_value  352091 non-null  float64
#  3   total_price   936712 non-null  float64
# dtypes: float64(4)
# memory usage: 38.1 MB

# %%
np.log10(tmp['total_price']).hist(bins=50, figsize=(8,5))
plt.xlabel("total_price")
plt.ylabel("Frequency")
plt.show()

# %%
# np.log10(tmp_log['total_price']).hist(bins=50, figsize=(8,5))
tmp_log['total_price'].hist(bins=50, figsize=(8,5))
plt.xlabel("total_price")
plt.ylabel("Frequency")
plt.show()

# %%
tmp['total_price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 997869 entries, 0 to 999999
# Series name: total_price
# Non-Null Count   Dtype
# --------------   -----
# 936712 non-null  float64
# dtypes: float64(1)
# memory usage: 15.2 MB

# %%
tmp['total_price'].to_csv('../../processed data/total_price.csv')
tmp_log['total_price'].to_csv('../../processed data/total_price_log.csv')
